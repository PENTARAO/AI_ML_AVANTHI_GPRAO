# %% [markdown]
# <a href="https://colab.research.google.com/github/PENTARAO/AI_ML_AVANTHI_GPRAO/blob/main/12_02_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import matplotlib.pyplot as plt
 import numpy as np
 import pandas as pd

# %%
df=pd.read_csv("/content/carprices (1).csv")

# %%
#x=df[['milage','Age(yrs)']]
x=df.drop('Sell Price($)',axis='columns')
y=df['Sell Price($)']

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train
# Out:
#     Mileage  Age(yrs)
# 5     59000         5
# 4     46000         4
# 3     22500         2
# 13    58780         4
# 9     67000         6
# 15    25400         3
# 8     91000         8
# 6     52000         5
# 18    87600         8
# 11    79000         7
# 12    59000         5
# 10    83000         7
# 2     57000         5
# 16    28000         2
# 0     69000         6
# 1     35000         3

# %%
import seaborn as sns

# %%
df = pd.read_csv('/content/1000_Companies.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
