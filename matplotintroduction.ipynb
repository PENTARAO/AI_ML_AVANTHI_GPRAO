# %% [markdown]
# <a href="https://colab.research.google.com/github/PENTARAO/AI_ML_AVANTHI_GPRAO/blob/main/matplotintroduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)

# %%
x=np.arange(0,10,2)
y=np.arange(0,15,3)
#plt.xticks=[2,4,]
plt.plot(x,y)
plt.title('OUR FIRST GRAPH',fontdict={'fontsize':50})
# Out:
# Text(0.5, 1.0, 'OUR FIRST GRAPH')
